# %%
import os
from ultralytics import YOLO
import cv2
import xgboost as xgb
import pandas as pd

def detect_shoplifting(video_path):
    model_yolo = YOLO(r"/Users/puttu/Desktop/FYP-shoplifting/FYP-shoplifting/best.pt")  # Updated path
    model = xgb.Booster()
    model.load_model(r"/Users/puttu/Desktop/FYP-shoplifting/FYP-shoplifting/model_weights.json")  # Update other paths similarly

    cap = cv2.VideoCapture(video_path)

    print('Total Frame', cap.get(cv2.CAP_PROP_FRAME_COUNT))

    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc('F', 'M', 'P', '4')
    
    # Generate a unique output path
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    output_path = fr"/Users/puttu/Desktop/FYP-shoplifting/FYP-shoplifting/output_video/{video_name}_output.mp4"  # Updated path
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    frame_tot = 0

    while cap.isOpened():
        success, frame = cap.read()

        if success:
            results = model_yolo(frame, verbose=False)

            # Visualize the results on the frame
            annotated_frame = results[0].plot(boxes=False)

            for r in results:
                bound_box = r.boxes.xyxy
                conf = r.boxes.conf.tolist()
                keypoints = r.keypoints.xyn.tolist()

                print(f'Frame {frame_tot}: Detected {len(bound_box)} bounding boxes')

                for index, box in enumerate(bound_box):
                    if conf[index] > 0.75:
                        x1, y1, x2, y2 = box.tolist()
                        data = {}

                        # Initialize the x and y lists for each possible key
                        for j in range(len(keypoints[index])):
                            data[f'x{j}'] = keypoints[index][j][0]
                            data[f'y{j}'] = keypoints[index][j][1]

                        # print(f'Bounding Box {index}: {data}')
                        df = pd.DataFrame(data, index=[0])
                        dmatrix = xgb.DMatrix(df)
                        cut = model.predict(dmatrix)
                        binary_predictions = (cut > 0.5).astype(int)
                        print(f'Prediction: {binary_predictions}')

                        if binary_predictions == 0:
                            conf_text = f'Suspicious ({conf[index]:.2f})'
                            cv2.rectangle(annotated_frame, (int(x1), int(y1)), (int(x2), int(y2)), (255, 7, 58), 2)
                            cv2.putText(annotated_frame, conf_text, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_DUPLEX, 1.0, (255, 7, 58), 2)
                        if binary_predictions == 1:
                            conf_text = f'Normal ({conf[index]:.2f})'
                            cv2.rectangle(annotated_frame, (int(x1), int(y1)), (int(x2), int(y2)), (57, 255, 20), 2)
                            cv2.putText(annotated_frame, conf_text, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_DUPLEX, 1.0, (57, 255, 20), 2)


            cv2.imshow('Frame', annotated_frame)

            out.write(annotated_frame)
            frame_tot += 1
            print('Processed Frame:', frame_tot)

            if cv2.waitKey(1) & 0xFF == ord("q"):
                break
        else:
            break

    cap.release()
    out.release()
    cv2.destroyAllWindows()

# Example usage:
video_path = r"/Users/puttu/Desktop/FYP-shoplifting/FYP-shoplifting/istockphoto-1391833001-640_adpp_is.mp4"  # Update the video path
detect_shoplifting(video_path)
# Out:
# Total Frame 423.0
# OpenCV: FFMPEG: tag 0x34504d46/'FMP4' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# [ WARN:0@2.562] global cap.cpp:781 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.11.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_images.cpp:267: error: (-215:Assertion failed) number < max_number in function 'icvExtractPattern'
# Frame 0: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 1
# Frame 1: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 2
# Frame 2: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 3
# Frame 3: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 4
# 2025-03-27 23:27:09.269 python[3850:7261298] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-27 23:27:09.269 python[3850:7261298] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# Frame 4: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 5
# Frame 5: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 6
# Frame 6: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 7
# Frame 7: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 8
# Frame 8: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 9
# Frame 9: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 10
# Frame 10: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 11
# Frame 11: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 12
# Frame 12: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 13
# Frame 13: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 14
# Frame 14: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 15
# Frame 15: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 16
# Frame 16: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 17
# Frame 17: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 18
# Frame 18: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 19
# Frame 19: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 20
# Frame 20: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 21
# Frame 21: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 22
# Frame 22: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 23
# Frame 23: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 24
# Frame 24: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 25
# Frame 25: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 26
# Frame 26: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 27
# Frame 27: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 28
# Frame 28: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 29
# Frame 29: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 30
# Frame 30: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 31
# Frame 31: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 32
# Frame 32: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 33
# Frame 33: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 34
# Frame 34: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 35
# Frame 35: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 36
# Frame 36: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 37
# Frame 37: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 38
# Frame 38: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 39
# Frame 39: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 40
# Frame 40: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 41
# Frame 41: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 42
# Frame 42: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 43
# Frame 43: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 44
# Frame 44: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 45
# Frame 45: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 46
# Frame 46: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 47
# Frame 47: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 48
# Frame 48: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 49
# Frame 49: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 50
# Frame 50: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 51
# Frame 51: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 52
# Frame 52: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 53
# Frame 53: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 54
# Frame 54: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 55
# Frame 55: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 56
# Frame 56: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 57
# Frame 57: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 58
# Frame 58: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 59
# Frame 59: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 60
# Frame 60: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 61
# Frame 61: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 62
# Frame 62: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 63
# Frame 63: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 64
# Frame 64: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 65
# Frame 65: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 66
# Frame 66: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 67
# Frame 67: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 68
# Frame 68: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 69
# Frame 69: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 70
# Frame 70: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 71
# Frame 71: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 72
# Frame 72: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 73
# Frame 73: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 74
# Frame 74: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 75
# Frame 75: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 76
# Frame 76: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 77
# Frame 77: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 78
# Frame 78: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 79
# Frame 79: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 80
# Frame 80: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 81
# Frame 81: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 82
# Frame 82: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 83
# Frame 83: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 84
# Frame 84: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 85
# Frame 85: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 86
# Frame 86: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 87
# Frame 87: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 88
# Frame 88: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 89
# Frame 89: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 90
# Frame 90: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 91
# Frame 91: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 92
# Frame 92: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 93
# Frame 93: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 94
# Frame 94: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 95
# Frame 95: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 96
# Frame 96: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 97
# Frame 97: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 98
# Frame 98: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 99
# Frame 99: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 100
# Frame 100: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 101
# Frame 101: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 102
# Frame 102: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 103
# Frame 103: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 104
# Frame 104: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 105
# Frame 105: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 106
# Frame 106: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 107
# Frame 107: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 108
# Frame 108: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 109
# Frame 109: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 110
# Frame 110: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 111
# Frame 111: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 112
# Frame 112: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 113
# Frame 113: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 114
# Frame 114: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 115
# Frame 115: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 116
# Frame 116: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 117
# Frame 117: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 118
# Frame 118: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 119
# Frame 119: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 120
# Frame 120: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 121
# Frame 121: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 122
# Frame 122: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 123
# Frame 123: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 124
# Frame 124: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 125
# Frame 125: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 126
# Frame 126: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 127
# Frame 127: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 128
# Frame 128: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 129
# Frame 129: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 130
# Frame 130: Detected 2 bounding boxes
# Processed Frame: 131
# Frame 131: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 132
# Frame 132: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 133
# Frame 133: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 134
# Frame 134: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 135
# Frame 135: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 136
# Frame 136: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 137
# Frame 137: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 138
# Frame 138: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 139
# Frame 139: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 140
# Frame 140: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 141
# Frame 141: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 142
# Frame 142: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 143
# Frame 143: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 144
# Frame 144: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 145
# Frame 145: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 146
# Frame 146: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 147
# Frame 147: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 148
# Frame 148: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 149
# Frame 149: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 150
# Frame 150: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 151
# Frame 151: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 152
# Frame 152: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 153
# Frame 153: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 154
# Frame 154: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 155
# Frame 155: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 156
# Frame 156: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 157
# Frame 157: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 158
# Frame 158: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 159
# Frame 159: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 160
# Frame 160: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 161
# Frame 161: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 162
# Frame 162: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 163
# Frame 163: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 164
# Frame 164: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 165
# Frame 165: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 166
# Frame 166: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 167
# Frame 167: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 168
# Frame 168: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 169
# Frame 169: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 170
# Frame 170: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 171
# Frame 171: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 172
# Frame 172: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 173
# Frame 173: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 174
# Frame 174: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 175
# Frame 175: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 176
# Frame 176: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 177
# Frame 177: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 178
# Frame 178: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 179
# Frame 179: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 180
# Frame 180: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 181
# Frame 181: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 182
# Frame 182: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 183
# Frame 183: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 184
# Frame 184: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 185
# Frame 185: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 186
# Frame 186: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 187
# Frame 187: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 188
# Frame 188: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 189
# Frame 189: Detected 3 bounding boxes
# Processed Frame: 190
# Frame 190: Detected 3 bounding boxes
# Processed Frame: 191
# Frame 191: Detected 3 bounding boxes
# Processed Frame: 192
# Frame 192: Detected 3 bounding boxes
# Processed Frame: 193
# Frame 193: Detected 4 bounding boxes
# Processed Frame: 194
# Frame 194: Detected 4 bounding boxes
# Processed Frame: 195
# Frame 195: Detected 4 bounding boxes
# Processed Frame: 196
# Frame 196: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 197
# Frame 197: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 198
# Frame 198: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 199
# Frame 199: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 200
# Frame 200: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 201
# Frame 201: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 202
# Frame 202: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 203
# Frame 203: Detected 3 bounding boxes
# Processed Frame: 204
# Frame 204: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 205
# Frame 205: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 206
# Frame 206: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 207
# Frame 207: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 208
# Frame 208: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 209
# Frame 209: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 210
# Frame 210: Detected 4 bounding boxes
# Processed Frame: 211
# Frame 211: Detected 3 bounding boxes
# Processed Frame: 212
# Frame 212: Detected 3 bounding boxes
# Processed Frame: 213
# Frame 213: Detected 4 bounding boxes
# Prediction: [0]
# Processed Frame: 214
